# %%
# ========================
# VGG16 - BRISC 2025 Classifier
# ========================

import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import matplotlib.pyplot as plt
import pickle

# === Data Augmentation ===
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,   
    vertical_flip=False,     
    validation_split=0.2,
    fill_mode='nearest'
)

train_generator = train_datagen.flow_from_directory(
    './archive/brisc2025/classification_task/train',
    target_size=(224, 224),
    color_mode='rgb',
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    './archive/brisc2025/classification_task/train',
    target_size=(224, 224),
    color_mode='rgb',
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
test_generator = test_datagen.flow_from_directory(
    './archive/brisc2025/classification_task/test',
    target_size=(224, 224),
    color_mode='rgb',
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# === Callbacks ===
early_stop = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, min_lr=1e-6)
checkpoint = ModelCheckpoint('./models/best_vgg16_model.h5', monitor='val_accuracy', save_best_only=True, verbose=1)

# === Base Model ===
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze base layers
for layer in base_model.layers:
    layer.trainable = False

# === Custom Classifier ===
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.Dropout(0.4),
    layers.Dense(4, activation='softmax')  # 4 classes
])

# === Compile ===
optimizer = Adam(learning_rate=1e-3)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# === Summary ===
model.summary()

# === Train ===
history = model.fit(
    train_generator,
    epochs=100,
    validation_data=val_generator,
    callbacks=[early_stop, reduce_lr, checkpoint]
)

# === Plot Accuracy ===
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title('VGG16 Accuracy Curve')
plt.show()
# Out:
# Found 4002 images belonging to 4 classes.
# Found 998 images belonging to 4 classes.
# Found 1000 images belonging to 4 classes.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)                   │ (None, 7, 7, 512)           │      14,714,688 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 512)                 │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │           1,028 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,848,068 (56.64 MB)
#  Trainable params: 132,868 (519.02 KB)
#  Non-trainable params: 14,715,200 (56.13 MB)
# C:\Users\Shaunak Mishra\Music\tensorfloww\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6906 - loss: 1.2302
# Epoch 1: val_accuracy improved from None to 0.80160, saving model to ./models/best_vgg16_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 436s 3s/step - accuracy: 0.7844 - loss: 0.9382 - val_accuracy: 0.8016 - val_loss: 1.1335 - learning_rate: 0.0010
# Epoch 2/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8668 - loss: 0.6521
# Epoch 2: val_accuracy improved from 0.80160 to 0.80862, saving model to ./models/best_vgg16_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 381s 3s/step - accuracy: 0.8668 - loss: 0.6420 - val_accuracy: 0.8086 - val_loss: 0.8055 - learning_rate: 0.0010
# Epoch 3/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9005 - loss: 0.5480
# Epoch 3: val_accuracy improved from 0.80862 to 0.82866, saving model to ./models/best_vgg16_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 376s 3s/step - accuracy: 0.8856 - loss: 0.5754 - val_accuracy: 0.8287 - val_loss: 0.8230 - learning_rate: 0.0010
# Epoch 4/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8931 - loss: 0.5371
# Epoch 4: val_accuracy improved from 0.82866 to 0.83267, saving model to ./models/best_vgg16_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.8903 - loss: 0.5265 - val_accuracy: 0.8327 - val_loss: 0.9363 - learning_rate: 0.0010
# Epoch 5/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9108 - loss: 0.4831
# Epoch 5: val_accuracy did not improve from 0.83267
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9073 - loss: 0.4875 - val_accuracy: 0.7224 - val_loss: 1.0146 - learning_rate: 0.0010
# Epoch 6/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9023 - loss: 0.4585
# Epoch 6: val_accuracy did not improve from 0.83267
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - accuracy: 0.9058 - loss: 0.4574 - val_accuracy: 0.8186 - val_loss: 0.8547 - learning_rate: 0.0010
# Epoch 7/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9135 - loss: 0.4305
# Epoch 7: val_accuracy did not improve from 0.83267
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9088 - loss: 0.4368 - val_accuracy: 0.8327 - val_loss: 0.6796 - learning_rate: 0.0010
# Epoch 8/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9129 - loss: 0.4130
# Epoch 8: val_accuracy did not improve from 0.83267
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 365s 3s/step - accuracy: 0.9113 - loss: 0.4160 - val_accuracy: 0.8056 - val_loss: 0.8547 - learning_rate: 0.0010
# Epoch 9/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9121 - loss: 0.4126
# Epoch 9: val_accuracy improved from 0.83267 to 0.86172, saving model to ./models/best_vgg16_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - accuracy: 0.9108 - loss: 0.4162 - val_accuracy: 0.8617 - val_loss: 0.6248 - learning_rate: 0.0010
# Epoch 10/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9180 - loss: 0.3795
# Epoch 10: val_accuracy did not improve from 0.86172
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - accuracy: 0.9125 - loss: 0.4026 - val_accuracy: 0.8277 - val_loss: 0.6554 - learning_rate: 0.0010
# Epoch 11/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9084 - loss: 0.4031
# Epoch 11: val_accuracy did not improve from 0.86172
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9098 - loss: 0.4085 - val_accuracy: 0.8146 - val_loss: 0.8609 - learning_rate: 0.0010
# Epoch 12/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9041 - loss: 0.4415
# Epoch 12: val_accuracy did not improve from 0.86172
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 365s 3s/step - accuracy: 0.9135 - loss: 0.3966 - val_accuracy: 0.8557 - val_loss: 0.6215 - learning_rate: 0.0010
# Epoch 13/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9191 - loss: 0.3671
# Epoch 13: val_accuracy did not improve from 0.86172
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 364s 3s/step - accuracy: 0.9195 - loss: 0.3635 - val_accuracy: 0.8277 - val_loss: 0.7320 - learning_rate: 0.0010
# Epoch 14/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9213 - loss: 0.3503
# Epoch 14: val_accuracy did not improve from 0.86172
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - accuracy: 0.9218 - loss: 0.3555 - val_accuracy: 0.8317 - val_loss: 0.6039 - learning_rate: 0.0010
# Epoch 15/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9282 - loss: 0.3378
# Epoch 15: val_accuracy improved from 0.86172 to 0.86373, saving model to ./models/best_vgg16_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - accuracy: 0.9295 - loss: 0.3326 - val_accuracy: 0.8637 - val_loss: 0.5623 - learning_rate: 5.0000e-04
# Epoch 16/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9285 - loss: 0.3332
# Epoch 16: val_accuracy improved from 0.86373 to 0.86573, saving model to ./models/best_vgg16_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 365s 3s/step - accuracy: 0.9255 - loss: 0.3343 - val_accuracy: 0.8657 - val_loss: 0.5301 - learning_rate: 5.0000e-04
# Epoch 17/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9210 - loss: 0.3300
# Epoch 17: val_accuracy improved from 0.86573 to 0.86874, saving model to ./models/best_vgg16_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 381s 3s/step - accuracy: 0.9228 - loss: 0.3272 - val_accuracy: 0.8687 - val_loss: 0.5462 - learning_rate: 5.0000e-04
# Epoch 18/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9325 - loss: 0.3094
# Epoch 18: val_accuracy did not improve from 0.86874
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 368s 3s/step - accuracy: 0.9293 - loss: 0.3106 - val_accuracy: 0.8607 - val_loss: 0.6036 - learning_rate: 5.0000e-04
# Epoch 19/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9313 - loss: 0.3149
# Epoch 19: val_accuracy did not improve from 0.86874
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 371s 3s/step - accuracy: 0.9240 - loss: 0.3211 - val_accuracy: 0.8417 - val_loss: 0.5466 - learning_rate: 5.0000e-04
# Epoch 20/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9294 - loss: 0.3170
# Epoch 20: val_accuracy did not improve from 0.86874
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 373s 3s/step - accuracy: 0.9283 - loss: 0.3195 - val_accuracy: 0.8467 - val_loss: 0.6260 - learning_rate: 5.0000e-04
# Epoch 21/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9299 - loss: 0.3095
# Epoch 21: val_accuracy did not improve from 0.86874
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9275 - loss: 0.3100 - val_accuracy: 0.8557 - val_loss: 0.5622 - learning_rate: 5.0000e-04
# Epoch 22/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9413 - loss: 0.2874
# Epoch 22: val_accuracy did not improve from 0.86874
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - accuracy: 0.9323 - loss: 0.3019 - val_accuracy: 0.8647 - val_loss: 0.5275 - learning_rate: 5.0000e-04
# Epoch 23/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9253 - loss: 0.3039
# Epoch 23: val_accuracy did not improve from 0.86874
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 368s 3s/step - accuracy: 0.9303 - loss: 0.2918 - val_accuracy: 0.8617 - val_loss: 0.6279 - learning_rate: 2.5000e-04
# Epoch 24/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9360 - loss: 0.2823
# Epoch 24: val_accuracy did not improve from 0.86874
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - accuracy: 0.9340 - loss: 0.2880 - val_accuracy: 0.8557 - val_loss: 0.5671 - learning_rate: 2.5000e-04
# Epoch 25/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9458 - loss: 0.2671
# Epoch 25: val_accuracy did not improve from 0.86874
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 365s 3s/step - accuracy: 0.9403 - loss: 0.2756 - val_accuracy: 0.8647 - val_loss: 0.5169 - learning_rate: 2.5000e-04
# Epoch 26/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9373 - loss: 0.2827
# Epoch 26: val_accuracy did not improve from 0.86874
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 365s 3s/step - accuracy: 0.9398 - loss: 0.2739 - val_accuracy: 0.8617 - val_loss: 0.6004 - learning_rate: 2.5000e-04
# Epoch 27/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9363 - loss: 0.2802
# Epoch 27: val_accuracy improved from 0.86874 to 0.87876, saving model to ./models/best_vgg16_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 372s 3s/step - accuracy: 0.9420 - loss: 0.2688 - val_accuracy: 0.8788 - val_loss: 0.5232 - learning_rate: 2.5000e-04
# Epoch 28/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9382 - loss: 0.2596
# Epoch 28: val_accuracy did not improve from 0.87876
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - accuracy: 0.9340 - loss: 0.2658 - val_accuracy: 0.8657 - val_loss: 0.5380 - learning_rate: 2.5000e-04
# Epoch 29/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9479 - loss: 0.2556
# Epoch 29: val_accuracy did not improve from 0.87876
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 370s 3s/step - accuracy: 0.9450 - loss: 0.2552 - val_accuracy: 0.8727 - val_loss: 0.5511 - learning_rate: 2.5000e-04
# Epoch 30/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9401 - loss: 0.2535
# Epoch 30: val_accuracy did not improve from 0.87876
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9448 - loss: 0.2451 - val_accuracy: 0.8697 - val_loss: 0.5514 - learning_rate: 2.5000e-04
# Epoch 31/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9448 - loss: 0.2485
# Epoch 31: val_accuracy did not improve from 0.87876
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 384s 3s/step - accuracy: 0.9458 - loss: 0.2446 - val_accuracy: 0.8617 - val_loss: 0.6105 - learning_rate: 2.5000e-04
# Epoch 32/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9436 - loss: 0.2441
# Epoch 32: val_accuracy improved from 0.87876 to 0.87976, saving model to ./models/best_vgg16_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9455 - loss: 0.2494 - val_accuracy: 0.8798 - val_loss: 0.4864 - learning_rate: 2.5000e-04
# Epoch 33/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9429 - loss: 0.2491
# Epoch 33: val_accuracy did not improve from 0.87976
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9418 - loss: 0.2483 - val_accuracy: 0.8788 - val_loss: 0.5197 - learning_rate: 2.5000e-04
# Epoch 34/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9406 - loss: 0.2384
# Epoch 34: val_accuracy did not improve from 0.87976
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 371s 3s/step - accuracy: 0.9405 - loss: 0.2423 - val_accuracy: 0.8778 - val_loss: 0.5212 - learning_rate: 2.5000e-04
# Epoch 35/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9475 - loss: 0.2348
# Epoch 35: val_accuracy did not improve from 0.87976
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - accuracy: 0.9483 - loss: 0.2299 - val_accuracy: 0.8707 - val_loss: 0.4827 - learning_rate: 2.5000e-04
# Epoch 36/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9427 - loss: 0.2312
# Epoch 36: val_accuracy did not improve from 0.87976
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 365s 3s/step - accuracy: 0.9440 - loss: 0.2372 - val_accuracy: 0.8727 - val_loss: 0.4595 - learning_rate: 2.5000e-04
# Epoch 37/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9465 - loss: 0.2374
# Epoch 37: val_accuracy did not improve from 0.87976
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - accuracy: 0.9455 - loss: 0.2391 - val_accuracy: 0.8778 - val_loss: 0.5290 - learning_rate: 2.5000e-04
# Epoch 38/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9506 - loss: 0.2244
# Epoch 38: val_accuracy did not improve from 0.87976
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - accuracy: 0.9500 - loss: 0.2247 - val_accuracy: 0.8687 - val_loss: 0.5328 - learning_rate: 1.2500e-04
# Epoch 39/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9563 - loss: 0.2057
# Epoch 39: val_accuracy did not improve from 0.87976
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 447s 4s/step - accuracy: 0.9513 - loss: 0.2187 - val_accuracy: 0.8647 - val_loss: 0.5199 - learning_rate: 1.2500e-04
# Epoch 40/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9484 - loss: 0.2148
# Epoch 40: val_accuracy did not improve from 0.87976
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 381s 3s/step - accuracy: 0.9483 - loss: 0.2199 - val_accuracy: 0.8798 - val_loss: 0.5211 - learning_rate: 1.2500e-04
# Epoch 41/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9434 - loss: 0.2480
# Epoch 41: val_accuracy improved from 0.87976 to 0.88878, saving model to ./models/best_vgg16_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 368s 3s/step - accuracy: 0.9470 - loss: 0.2308 - val_accuracy: 0.8888 - val_loss: 0.4795 - learning_rate: 1.2500e-04
# Epoch 42/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9522 - loss: 0.2023
# Epoch 42: val_accuracy did not improve from 0.88878
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 384s 3s/step - accuracy: 0.9533 - loss: 0.2034 - val_accuracy: 0.8647 - val_loss: 0.5727 - learning_rate: 1.2500e-04
# Epoch 43/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9429 - loss: 0.2167
# Epoch 43: val_accuracy did not improve from 0.88878
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - accuracy: 0.9493 - loss: 0.2146 - val_accuracy: 0.8727 - val_loss: 0.4889 - learning_rate: 1.2500e-04
# Epoch 44/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9491 - loss: 0.2143
# Epoch 44: val_accuracy did not improve from 0.88878
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - accuracy: 0.9490 - loss: 0.2187 - val_accuracy: 0.8707 - val_loss: 0.5050 - learning_rate: 1.2500e-04
# Epoch 45/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9662 - loss: 0.1899
# Epoch 45: val_accuracy did not improve from 0.88878
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.9605 - loss: 0.1956 - val_accuracy: 0.8808 - val_loss: 0.5015 - learning_rate: 1.2500e-04
# Epoch 46/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9559 - loss: 0.1982
# Epoch 46: val_accuracy did not improve from 0.88878
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 373s 3s/step - accuracy: 0.9563 - loss: 0.1980 - val_accuracy: 0.8747 - val_loss: 0.5081 - learning_rate: 1.2500e-04
# Epoch 47/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9546 - loss: 0.2017
# Epoch 47: val_accuracy improved from 0.88878 to 0.89178, saving model to ./models/best_vgg16_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9545 - loss: 0.2041 - val_accuracy: 0.8918 - val_loss: 0.4723 - learning_rate: 6.2500e-05
# Epoch 48/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9543 - loss: 0.2044
# Epoch 48: val_accuracy did not improve from 0.89178
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 381s 3s/step - accuracy: 0.9563 - loss: 0.1955 - val_accuracy: 0.8727 - val_loss: 0.5009 - learning_rate: 6.2500e-05
# Epoch 49/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9442 - loss: 0.2175
# Epoch 49: val_accuracy did not improve from 0.89178
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9508 - loss: 0.2040 - val_accuracy: 0.8768 - val_loss: 0.5109 - learning_rate: 6.2500e-05
# Epoch 50/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9509 - loss: 0.1984
# Epoch 50: val_accuracy did not improve from 0.89178
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 368s 3s/step - accuracy: 0.9578 - loss: 0.1911 - val_accuracy: 0.8677 - val_loss: 0.5523 - learning_rate: 6.2500e-05
# Epoch 51/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9537 - loss: 0.2023
# Epoch 51: val_accuracy did not improve from 0.89178
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 368s 3s/step - accuracy: 0.9588 - loss: 0.1961 - val_accuracy: 0.8808 - val_loss: 0.5360 - learning_rate: 6.2500e-05
# Epoch 52/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9546 - loss: 0.1929
# Epoch 52: val_accuracy did not improve from 0.89178
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 382s 3s/step - accuracy: 0.9568 - loss: 0.1944 - val_accuracy: 0.8878 - val_loss: 0.5327 - learning_rate: 6.2500e-05
# Epoch 53/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9558 - loss: 0.1896
# Epoch 53: val_accuracy did not improve from 0.89178
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 383s 3s/step - accuracy: 0.9580 - loss: 0.1897 - val_accuracy: 0.8838 - val_loss: 0.5297 - learning_rate: 3.1250e-05
# Epoch 54/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9531 - loss: 0.1967
# Epoch 54: val_accuracy did not improve from 0.89178
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 382s 3s/step - accuracy: 0.9538 - loss: 0.1972 - val_accuracy: 0.8838 - val_loss: 0.5037 - learning_rate: 3.1250e-05
# Epoch 55/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9588 - loss: 0.1838
# Epoch 55: val_accuracy did not improve from 0.89178
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 381s 3s/step - accuracy: 0.9565 - loss: 0.1902 - val_accuracy: 0.8717 - val_loss: 0.5585 - learning_rate: 3.1250e-05
# Epoch 56/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9594 - loss: 0.1843
# Epoch 56: val_accuracy did not improve from 0.89178
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 375s 3s/step - accuracy: 0.9595 - loss: 0.1876 - val_accuracy: 0.8838 - val_loss: 0.4961 - learning_rate: 3.1250e-05
# Epoch 57/100
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9573 - loss: 0.1976
# Epoch 57: val_accuracy did not improve from 0.89178
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 371s 3s/step - accuracy: 0.9590 - loss: 0.1918 - val_accuracy: 0.8888 - val_loss: 0.4922 - learning_rate: 3.1250e-05
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 95
#      87 history = model.fit(
#      88     train_generator,
#      89     epochs=100,
#      90     validation_data=val_generator,
#      91     callbacks=[early_stop, reduce_lr, checkpoint]
#      92 )
#      94 # === Save Training History ===
# ---> 95 with open('./models/history/vgg_history.pkl', 'wb') as f:
#      96     pickle.dump(history.history, f)
#      98 # === Plot Accuracy ===
#
# File ~\Music\tensorfloww\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './models/history/vgg_history.pkl'

# %%
import matplotlib.pyplot as plt

# Accuracy plot
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Train vs Validation Accuracy')
plt.legend()

# Loss plot
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train vs Validation Loss')
plt.legend()

plt.show()

# %%
import numpy as np

# Predict probabilities
y_pred_probs = model.predict(test_generator)

# Convert to class indices
y_pred = np.argmax(y_pred_probs, axis=1)

# True labels
y_true = test_generator.classes
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print(f'Test Accuracy: {accuracy*100:.2f}%')
print(f'Test Precision: {precision*100:.2f}%')
print(f'Test Recall: {recall*100:.2f}%')
print(f'Test F1 Score: {f1*100:.2f}%')

# Detailed per-class report
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=list(test_generator.class_indices.keys())))
# Out:
# Test Accuracy: 86.90%
# Test Precision: 86.95%
# Test Recall: 86.90%
# Test F1 Score: 86.56%
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       glioma       0.89      0.83      0.86       254
#   meningioma       0.86      0.74      0.79       306
#     no_tumor       0.84      0.98      0.90       140
#    pituitary       0.87      0.99      0.93       300
#
#     accuracy                           0.87      1000
#    macro avg       0.87      0.88      0.87      1000
# weighted avg       0.87      0.87      0.87      1000
